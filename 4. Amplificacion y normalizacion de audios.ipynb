# %% [markdown]
# ### Librerias

# %%
# procesamiento
import os
import pandas as pd
import numpy as np
import swifter

# analisis de audio
import ffmpeg
from gtts import gTTS
import pyttsx3
from scipy.io import wavfile
from pydub import AudioSegment
#pip install eyeD3
#pip install pydub
#pip install ffmpeg-python
from pyAudioAnalysis import ShortTermFeatures as aF
from pyAudioAnalysis import audioBasicIO as aIO 

import os
import traceback
import operator

import numpy as np
import cv2
import soundfile as sf 
import scipy.io.wavfile as wave
import scipy.ndimage as ndimage
import scipy.stats as stats
from scipy import interpolate

import python_speech_features as psf
from pydub import AudioSegment

# %% [markdown]
# ### Carga, amplificación y normalización

# %%
directorio = os.path.join(os.getcwd(), "F:/sonidos aves/prueba concepto/Audios_Identificados_Corpus")
categorias = os.listdir(directorio)
amplificados = os.path.join(os.getcwd(), "F:/sonidos aves/prueba concepto/amplificados")

for i in range(len(categorias)):
    cat = os.listdir(directorio+"/"+categorias[i])
    for j in range(len(cat)):
        audio = AudioSegment.from_wav(directorio+"/"+categorias[i]+"/"+cat[j])
        audio = audio + 15
        audio.export(amplificados+"/"+categorias[i]+"/"+cat[j], "wav")
        fs_wav, data_wav = wavfile.read(amplificados+"/"+categorias[i]+"/"+cat[j])
        data_norm = data_wav / (2**15)
        wavfile.write(amplificados+"/"+categorias[i]+"/"+cat[j], fs_wav, data_norm)
    print("Audios de la categoria " + categorias[i] + " amplificados!")
# Out:
# Audios de la categoria Dysithamnus mentalis_Plain Antvireo amplificados!
# Audios de la categoria Herpetotheres cachinnans_Laughing Falcon amplificados!
# Audios de la categoria Megaceryle torquata_Ringed Kingfisher amplificados!
# Audios de la categoria Megarynchus pitangua_Boat-billed Flycatcher amplificados!
# Audios de la categoria Myiozetetes cayanensis_Rusty-margined Flycatcher amplificados!
# Audios de la categoria Pionus menstruus_Blue-headed Parrot amplificados!
# Audios de la categoria Pitangus sulphuratus_Great Kiskadee amplificados!
# Audios de la categoria Sicalis flaveola_Saffron Finch amplificados!
# Audios de la categoria Tyrannus melancholicus_Tropical Kingbird amplificados!
# Audios de la categoria Xenops rutilans_Streaked Xenops amplificados!

# %% [markdown]
# ### Procesamiento de audios - Ventana deslizante

# %%
#Specify the source folder containing subfolders named after genus, species and class id
#Use birdCLEF_sort_data.py in order to sort wav files accordingly
src_dir = "F:/sonidos aves/prueba concepto/amplificados/"

#Specify the target folder for spectrograms
#Will also contain subfolders named after genera, species and class ids of the processed wav files
#Will also contain "noise" folder with rejected spectrograms for further inspection
spec_dir = 'F:/sonidos aves/prueba concepto/espectrogramas/'

#Specify maximum number of spectrograms per species (-1 = No limit)
MAX_SPECS = -1

#Limit number of species? (None = No limit)
MAX_SPECIES = None

######################################################
#Change sample rate if not 44.1 kHz
def changeSampleRate(sig, rate):

    duration = sig.shape[0] / rate

    time_old  = np.linspace(0, duration, sig.shape[0])
    time_new  = np.linspace(0, duration, int(sig.shape[0] * 44100 / rate))

    interpolator = interpolate.interp1d(time_old, sig.T)
    new_audio = interpolator(time_new).T

    sig = np.round(new_audio).astype(sig.dtype)
    
    return sig, 44100

#Get magnitude spec from signal split
def getMagSpec(sig, rate, winlen, winstep, NFFT):

    #get frames
    winfunc = lambda x:np.ones((x,))
    frames = psf.sigproc.framesig(sig, winlen*rate, winstep*rate, winfunc)        
    
    #Magnitude Spectrogram
    magspec = np.rot90(psf.sigproc.magspec(frames, NFFT))

    return magspec

#Split signal into five-second chunks with overlap of 4 and minimum length of 3 seconds
#Use these settings for other chunk lengths:
#winlen, winstep, seconds
#0.05, 0.0097, 5s
#0.05, 0.0195, 10s
#0.05, 0.0585, 30s
def getMultiSpec(path, seconds=5, overlap=4, minlen=3, winlen=0.05, winstep=0.0097, NFFT=2205):

    #open wav file
    #(rate,sig) = wave.read(path)
    sig, rate = sf.read(path)  
    print ("SampleRate:", rate)

    #adjust to different sample rates
    if rate != 44100:
        sig, rate = changeSampleRate(sig, rate)

    #split signal with ovelap
    sig_splits = []
    for i in range(0, len(sig), int((seconds - overlap) * rate)):
        split = sig[i:i + seconds * rate]
        if len(split) >= minlen * rate:
            sig_splits.append(split)

    #is signal too short for segmentation?
    #append it anyway
    if len(sig_splits) == 0:
        sig_splits.append(sig)

    #calculate spectrogram for every split
    for sig in sig_splits:

        #preemphasis
        sig = psf.sigproc.preemphasis(sig, coeff=0.95)

        #get spec
        magspec = getMagSpec(sig, rate, winlen, winstep, NFFT)

        #get rid of high frequencies
        h, w = magspec.shape[:2]
        magspec = magspec[h - 256:, :]

        #normalize in [0, 1]
        magspec -= magspec.min(axis=None)
        magspec /= magspec.max(axis=None)        

        #fix shape to 512x256 pixels without distortion
        magspec = magspec[:256, :512]
        temp = np.zeros((256, 512), dtype="float32")
        temp[:magspec.shape[0], :magspec.shape[1]] = magspec
        magspec = temp.copy()
        magspec = cv2.resize(magspec, (224, 224))
        
        #DEBUG: show spec
        #cv2.imshow('SPEC', magspec)
        #cv2.waitKey(-1)

        yield magspec

#Remove single spots from an image
def filter_isolated_cells(array, struct):

    filtered_array = np.copy(array)
    id_regions, num_ids = ndimage.label(filtered_array, structure=struct)
    id_sizes = np.array(ndimage.sum(array, id_regions, range(num_ids + 1)))
    area_mask = (id_sizes == 1)
    filtered_array[area_mask[id_regions]] = 0
    
    return filtered_array

#Decide if given spectrum shows bird sounds or noise only
def hasBird(spec, threshold=16):

    #working copy
    img = spec.copy()

    #STEP 1: Median blur
    img = cv2.medianBlur(img,5)

    #STEP 2: Median threshold
    col_median = np.median(img, axis=0, keepdims=True)
    row_median = np.median(img, axis=1, keepdims=True)

    img[img < row_median * 3] = 0
    img[img < col_median * 4] = 0
    img[img > 0] = 1

    #STEP 3: Remove singles
    img = filter_isolated_cells(img, struct=np.ones((3,3)))

    #STEP 4: Morph Closing
    img = cv2.morphologyEx(img, cv2.MORPH_CLOSE, np.ones((5,5), np.float32))

    #STEP 5: Frequency crop
    img = img[128:-16, :]

    #STEP 6: Count columns and rows with signal
    #(Note: We only use rows with signal as threshold, but columns might come in handy in other scenarios)

    #column has signal?
    col_max = np.max(img, axis=0)
    col_max = ndimage.morphology.binary_dilation(col_max, iterations=2).astype(col_max.dtype)
    cthresh = col_max.sum()

    #row has signal?
    row_max = np.max(img, axis=1)
    row_max = ndimage.morphology.binary_dilation(row_max, iterations=2).astype(row_max.dtype)
    rthresh = row_max.sum()

    #final threshold
    thresh = rthresh

    #DBUGB: show?
    #print thresh
    #cv2.imshow('BIRD?', img)
    #cv2.waitKey(-1)

    #STEP 7: Apply threshold (Default = 16)
    bird = True
    if thresh < threshold:
        bird = False
    
    return bird, thresh

######################################################

#elist all bird species
#birds = [src_dir + bird + '/' for bird in sorted(os.listdir(src_dir))][:MAX_SPECIES]
birds = sorted(set([dp + '/' for dp, dn, filenames in os.walk(src_dir) for f in filenames if os.path.splitext(f)[1] == '.wav']))[:MAX_SPECIES]
print ("BIRDS:", len(birds))
#parse bird species
for bird in birds:
    total_specs = 0
    
    #get all wav files
    wav_files = [bird + wav for wav in sorted(os.listdir(bird))]

    #parse wav files
    for wav in wav_files:
        spec_cnt = 0
        print( wav)
        
        try:
            #get every spec from each wav file
            for spec in getMultiSpec(wav):

                #does spec contain bird sounds?
                isbird, thresh = hasBird(spec)

                #new target path -> rejected specs will be copied to "noise" folder
                #if isbird:
                dst_dir = spec_dir + bird.split("/")[-2] + "/"
                #else:
                    #dst_dir = spec_dir + "noise/" + bird.split("/")[-2] + "/"

                #make target dir
                if not os.path.exists(dst_dir):
                    os.makedirs(dst_dir)
                    
                #write spec to target dir
                cv2.imwrite(dst_dir +  wav.split("/")[-1].rsplit(".")[0] + "_" + str(spec_cnt) + ".png", spec * 255.0)
                
                spec_cnt += 1
                total_specs += 1

            #exceeded spec limit?
            if total_specs >= MAX_SPECS and MAX_SPECS > -1:
                print (" ")
                break
            
            print ("SPECS:", spec_cnt)

        except:
            print (spec_cnt, "ERROR")
            traceback.print_exc()
            pass
# Out:
# BIRDS: 10
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_2915.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_2965.wav
# SampleRate: 22050
# C:\Users\corvi\AppData\Local\Temp\ipykernel_13284\2562183556.py:145: DeprecationWarning: Please use `binary_dilation` from the `scipy.ndimage` namespace, the `scipy.ndimage.morphology` namespace is deprecated.
#   col_max = ndimage.morphology.binary_dilation(col_max, iterations=2).astype(col_max.dtype)
# C:\Users\corvi\AppData\Local\Temp\ipykernel_13284\2562183556.py:150: DeprecationWarning: Please use `binary_dilation` from the `scipy.ndimage` namespace, the `scipy.ndimage.morphology` namespace is deprecated.
#   row_max = ndimage.morphology.binary_dilation(row_max, iterations=2).astype(row_max.dtype)
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_2967.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_2968.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_3034.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_3037.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_3038.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_3041.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_3049.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_3311.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_3312.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_3313.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_3362.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_3365.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_3376.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_051602_toma_3379.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_1128.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_1267.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_1268.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_1270.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_1297.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_2658.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_2677.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_2691.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_611.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_614.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_672.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_815.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_893.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_951.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_952.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_061602_toma_954.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_071602_toma_3199.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_071602_toma_3201.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_071602_toma_3204.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_133.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_142.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_145.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_148.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_151.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_157.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_235.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_238.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_239.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_300.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_320.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_332.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_35.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_36.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_37.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_39.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_391.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_394.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_409.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_417.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_418.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_420.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_421.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_50.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_503.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_505.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_506.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_512.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_513.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_514.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_515.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_520.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_521.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_53.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_55.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_78.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_79.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Dysithamnus mentalis_Plain Antvireo/Dysithamnus mentalis_Plain Antvireo_SMU04082_20240309_081602_toma_80.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Herpetotheres cachinnans_Laughing Falcon/Herpetotheres cachinnans_Laughing Falcon_SMU04082_20240309_081602_toma_452.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Herpetotheres cachinnans_Laughing Falcon/Herpetotheres cachinnans_Laughing Falcon_SMU04082_20240309_081602_toma_455.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Megaceryle torquata_Ringed Kingfisher/Megaceryle torquata_Ringed Kingfisher_SMU04082_20240309_081602_toma_82.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Megarynchus pitangua_Boat-billed Flycatcher/Megarynchus pitangua_Boat-billed Flycatcher_SMU04082_20240309_051602_toma_3331.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Megarynchus pitangua_Boat-billed Flycatcher/Megarynchus pitangua_Boat-billed Flycatcher_SMU04082_20240309_061602_toma_1287.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Myiozetetes cayanensis_Rusty-margined Flycatcher/Myiozetetes cayanensis_Rusty-margined Flycatcher_SMU04082_20240309_061602_toma_1206.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pionus menstruus_Blue-headed Parrot/Pionus menstruus_Blue-headed Parrot_SMU04082_20240309_051602_toma_3199.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pionus menstruus_Blue-headed Parrot/Pionus menstruus_Blue-headed Parrot_SMU04082_20240309_051602_toma_3201.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pionus menstruus_Blue-headed Parrot/Pionus menstruus_Blue-headed Parrot_SMU04082_20240309_051602_toma_3202.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pionus menstruus_Blue-headed Parrot/Pionus menstruus_Blue-headed Parrot_SMU04082_20240309_051602_toma_3203.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pionus menstruus_Blue-headed Parrot/Pionus menstruus_Blue-headed Parrot_SMU04082_20240309_081602_toma_486.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pionus menstruus_Blue-headed Parrot/Pionus menstruus_Blue-headed Parrot_SMU04082_20240309_081602_toma_487.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pionus menstruus_Blue-headed Parrot/Pionus menstruus_Blue-headed Parrot_SMU04082_20240309_081602_toma_488.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pionus menstruus_Blue-headed Parrot/Pionus menstruus_Blue-headed Parrot_SMU04082_20240309_081602_toma_489.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pionus menstruus_Blue-headed Parrot/Pionus menstruus_Blue-headed Parrot_SMU04082_20240309_081602_toma_490.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pionus menstruus_Blue-headed Parrot/Pionus menstruus_Blue-headed Parrot_SMU04082_20240309_081602_toma_491.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pionus menstruus_Blue-headed Parrot/Pionus menstruus_Blue-headed Parrot_SMU04082_20240309_081602_toma_85.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pionus menstruus_Blue-headed Parrot/Pionus menstruus_Blue-headed Parrot_SMU04082_20240309_081602_toma_86.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pionus menstruus_Blue-headed Parrot/Pionus menstruus_Blue-headed Parrot_SMU04082_20240309_081602_toma_87.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pionus menstruus_Blue-headed Parrot/Pionus menstruus_Blue-headed Parrot_SMU04082_20240309_081602_toma_89.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3178.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3179.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3180.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3182.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3184.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3185.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3186.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3187.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3188.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3189.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3193.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3194.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3317.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3320.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3321.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3322.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3323.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3324.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3325.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3326.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3327.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3330.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3333.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3334.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3336.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3337.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3338.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3339.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3340.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_051602_toma_3393.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1003.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1006.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1011.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1014.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1015.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1019.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1022.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1024.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1028.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1030.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1073.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1074.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1075.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1076.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1077.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1078.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1079.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1086.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1087.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1088.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1089.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1090.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1091.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1092.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1093.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1094.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1097.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1328.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1329.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1330.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1331.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1332.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1644.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1650.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1651.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1652.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1653.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1654.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1655.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_1669.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2568.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2569.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2570.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2571.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2581.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2582.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2584.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2585.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2586.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2587.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2588.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2589.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2590.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2591.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2593.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2594.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2595.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2596.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2598.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2599.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2600.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2601.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2602.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2603.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2604.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2605.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2606.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2608.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2609.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2610.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2612.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2613.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2615.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2617.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2618.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2619.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2620.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2621.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2627.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2628.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2629.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2633.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2635.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2636.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2637.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2638.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2639.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2640.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2641.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2642.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2647.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2648.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2649.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2650.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2651.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2652.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2659.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2660.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2661.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2662.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2663.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2668.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2669.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2670.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2671.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2672.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2681.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2682.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2683.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2684.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2685.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2692.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2832.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2833.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2834.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2835.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2836.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2837.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2838.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2839.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2840.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2841.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2842.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2843.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2844.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2845.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2846.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2847.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2865.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2867.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2885.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2886.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2888.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2889.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2890.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_061602_toma_2891.wav
# ...
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_071602_toma_348.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_071602_toma_349.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_081602_toma_397.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_081602_toma_481.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1344.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1364.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1365.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1366.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1367.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1368.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1369.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1370.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1372.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1373.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1374.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1375.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1376.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1377.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1378.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_1379.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_252.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_253.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_256.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_257.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_258.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_259.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_265.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_270.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_280.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_283.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_285.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_291.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_305.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_310.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_330.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_331.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_332.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_334.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_432.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_451.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_452.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_453.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_454.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_455.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_459.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Pitangus sulphuratus_Great Kiskadee/Pitangus sulphuratus_Great Kiskadee_SMU04082_20240309_111602_toma_462.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2790.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2791.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2793.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2794.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2795.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2801.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2811.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2812.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2813.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2814.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2815.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2837.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2839.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2840.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2842.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2843.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_2992.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_051602_toma_3019.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_061602_toma_1025.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_061602_toma_1119.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_061602_toma_1120.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_061602_toma_1122.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_061602_toma_1256.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_061602_toma_822.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_061602_toma_825.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_061602_toma_826.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_111602_toma_2370.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_111602_toma_3088.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_111602_toma_3089.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_111602_toma_3090.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_111602_toma_3091.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_111602_toma_3092.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_111602_toma_3093.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_111602_toma_3098.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_111602_toma_3100.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Sicalis flaveola_Saffron Finch/Sicalis flaveola_Saffron Finch_SMU04082_20240309_111602_toma_458.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Tyrannus melancholicus_Tropical Kingbird/Tyrannus melancholicus_Tropical Kingbird_SMU04082_20240309_061602_toma_1668.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Tyrannus melancholicus_Tropical Kingbird/Tyrannus melancholicus_Tropical Kingbird_SMU04082_20240309_061602_toma_2623.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Tyrannus melancholicus_Tropical Kingbird/Tyrannus melancholicus_Tropical Kingbird_SMU04082_20240309_061602_toma_2626.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Tyrannus melancholicus_Tropical Kingbird/Tyrannus melancholicus_Tropical Kingbird_SMU04082_20240309_061602_toma_2900.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Tyrannus melancholicus_Tropical Kingbird/Tyrannus melancholicus_Tropical Kingbird_SMU04082_20240309_171602_toma_22.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Tyrannus melancholicus_Tropical Kingbird/Tyrannus melancholicus_Tropical Kingbird_SMU04082_20240309_171602_toma_25.wav
# SampleRate: 22050
# SPECS: 3
# F:/sonidos aves/prueba concepto/amplificados/Xenops rutilans_Streaked Xenops/Xenops rutilans_Streaked Xenops_SMU04082_20240309_081602_toma_159.wav
# SampleRate: 22050
# SPECS: 3
